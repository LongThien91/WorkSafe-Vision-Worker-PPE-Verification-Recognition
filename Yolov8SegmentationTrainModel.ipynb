# %% [markdown]
# #Install Yolov8

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 367.3 kB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %% [markdown]
# #Import Library

# %%
from ultralytics import YOLO

# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np
import tqdm

# %% [markdown]
# #Mount Data From Google driver

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip '/content/gdrive/MyDrive/people_test.v2i.yolov8.zip'
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#  extracting: train/images/Photo-on-10-26-21-at-2-33-PM-2_jpg.rf.d3b91eb1be9b9625e899ae404ab4d6eb.jpg
#  extracting: train/images/Photo-on-10-26-21-at-2-33-PM-3_jpg.rf.22b978dfb12ac9ba0d4cb787c398cf98.jpg
#  extracting: train/images/Photo-on-10-26-21-at-2-33-PM-3_jpg.rf.44a9c38f363665075b921425df74744c.jpg
#  extracting: train/images/Photo-on-10-26-21-at-2-33-PM-3_jpg.rf.6dee30d418cb60733844613b0c05122c.jpg
#  extracting: train/images/Photo-on-10-26-21-at-2-33-PM-4-2_jpg.rf.8be23687ee4ddbe8a121052efcd9fd38.jpg
#  extracting: train/images/Photo-on-10-26-21-at-2-33-PM-4-2_jpg.rf.927187df23fa01fe5a7054a012b1fd00.jpg
#  extracting: train/images/Photo-on-10-26-21-at-2-33-PM-4-2_jpg.rf.e9967fe519e7afe83066eb0d734c91a7.jpg
#  extracting: train/images/Photo-on-10-26-21-at-2-37-PM-2_jpg.rf.0ec01d3b59ac6febc1deb3506001a018.jpg
#  extracting: train/images/Photo-on-10-26-21-at-2-37-PM-2_jpg.rf.6655166aabe24b97d86e2a724538364b.jpg
# ...

# %% [markdown]
# #Train Model

# %%
# !yolo task=segment mode=train model=yolov8m-seg.pt data={'/content/data.yaml'} epochs=100 imgsz=512
# Out:
# ...
# 100% 52.4M/52.4M [00:01<00:00, 39.5MB/s]
# Ultralytics YOLOv8.2.79 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# #Test Model On Test Set

# %%
filenames = [f for f in os.listdir('/content/test/images') if f.endswith(('.jpg', '.jpeg', '.png'))]

# %%
model = YOLO('/content/runs/segment/train/weights/best.pt')

# %%
for i in range(0,len(filenames)):
  image_path = f'/content/test/images/{filenames[i]}'
  results= model.predict(source=image_path,conf=0.5, save=True)
# Out:
# image 1/1 /content/test/images/000000294663_jpg.rf.ac0b8a54ca024f1a5fb736eb37032a73.jpg: 512x512 1 person, 51.6ms
# Speed: 3.1ms preprocess, 51.6ms inference, 815.6ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs/segment/predict
#
# image 1/1 /content/test/images/000000133369_jpg.rf.115c021ac8e97f1b07d4dfaccf04f0fa.jpg: 512x512 1 person, 51.6ms
# Speed: 2.7ms preprocess, 51.6ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs/segment/predict
#
# image 1/1 /content/test/images/000000226541_jpg.rf.3d25b39db85cbbcde901d71bc6da4a7a.jpg: 512x512 5 persons, 51.5ms
# Speed: 1.7ms preprocess, 51.5ms inference, 5.7ms postprocess per image at shape (1, 3, 512, 512)
# Results saved to runs/segment/predict
#
# image 1/1 /content/test/images/000000051750_jpg.rf.e7b864bd17e2a758e41fa77adaa63b35.jpg: 512x512 11 persons, 40.5ms
# Speed: 2.8ms preprocess, 40.5ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 512)
# ...

# %%
from IPython.display import Image,display

# %%
img_paths = [f for f in os.listdir('/content/runs/segment/predict') if f.endswith(('.jpg', '.jpeg', '.png'))]

# %%
img_paths

# %%
for img_path in img_paths:
  image_path = f'/content/runs/segment/predict/{img_path}'
  display(Image(filename=image_path, height=224))
  print('\n')

# %%
img_path='/content/test/images/000000064350_jpg.rf.c1b50ede482d10eb9fc49f881d0f0b34.jpg'
results= model.predict(source=img_path,conf=0.5, save=True)
# Out:
# image 1/1 /content/test/images/000000064350_jpg.rf.c1b50ede482d10eb9fc49f881d0f0b34.jpg: 224x224 3 persons, 27.4ms
# Speed: 1.3ms preprocess, 27.4ms inference, 10.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/segment/predict3
